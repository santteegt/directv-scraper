# %% [markdown]
# # Directv Programming Guide - Data Cleaning & Validation process
#
# This notebook aim is to clean and validate data scrapped from the Directv programming guide using a Scrapy spider
#
# Author [@santteegt](https://santteegt.github.io)

# %%
import pandas as pd
import json
import requests
import hashlib

# %%
scrapy_project = 'directvscrapper'
spider = 'directv'
job_id = ''

# %% [markdown]
# ## Scheduling Directv spider on Scrapy server
#
# **NOTE**: Skip the cell below If spider has alredy been scheduled

# %%
rs = requests.post('http://localhost:6800/schedule.json', data={'project': scrapy_project, 'spider': spider})
json_rs = json.loads(rs.text)
print(json_rs)
if json_rs['status'] == 'error':
    print('ERROR -> %s' % json_rs['message'])
else:
    job_id = json_rs['jobid']
    print('Spider has been scheduled. Job id -> %s' % job_id)
# Out:
# {'jobid': '5a57a8dcccad11e897600242ac110002', 'node_name': '7f9006259b53', 'status': 'ok'}
# Spider has been scheduled. Job id -> 5a57a8dcccad11e897600242ac110002

# %% [markdown]
# ## Data Cleaning & Validation
#
# **IMPORTANT**: After the scraping process finished, run the following cells

# %%
scrapy_data_dir = 'data/items/directvscrapper/directv/'

json_file = '093df40c760e11e793300242ac110002.jl' if not job_id else job_id + '.jl'
json_guide = 'scrapped_data/programming_guide.json'
json_desc = 'scrapped_data/programming_desc.json'

# %%
! mkdir scrapped_data
# Out:
# mkdir: scrapped_data: File exists

# %%
programming_guide = []
programming_desc = []

with open(scrapy_data_dir + json_file, encoding='utf-8') as f:
    while True:
        json_line = f.readline()
        if not json_line:
            break
        
        jl = json.loads(json_line)
        [programming_guide.append(jl) if 'show_id' in jl else programming_desc.append(jl)]


with open(json_guide, 'w') as f_guide:
    json.dump(programming_guide, f_guide)
#     [f_guide.write(json.dumps(j) + '\n') for j in programming_guide]
#     f_guide.write(json.dumps(programming_guide))
    f_guide.close()
    
with open(json_desc, 'w') as f_desc:
    json.dump(programming_desc, f_desc)
#     [f_desc.write(json.dumps(j) + '\n') for j in programming_desc]
#     f_desc.write(json.dumps(programming_desc))
    f_desc.close()
    

print(len(programming_guide))
print(len(programming_desc))
# Out:
# 35369
# 15685

# %%
# df_guide = pd.read_csv(json_guide)
df_guide = pd.io.json.json_normalize(programming_guide)
df_guide['query_date'] = pd.to_datetime(df_guide['query_date'])
print(df_guide.shape)
df_guide.head()
# Out:
# (35369, 8)
#   channel_name  channel_number        day          query_date        show_id  \
# 0         INFO             100  Miércoles 2018-10-10 12:00:00   281247488289
# 1          101             101  Miércoles 2018-10-10 12:00:00  4140246043023
# 2         AINF             128  Miércoles 2018-10-10 12:00:00   128247668099
# 3         TLEC             177  Miércoles 2018-10-10 12:00:00   433247626775
# 4           TA             180  Miércoles 2018-10-10 12:00:00   180247762324
#
#   start_time time_length                      title
# 0      10:00         360  Canal Informativo DIRECTV
# 1      10:00         360                  Canal 101
# 2      12:00          30                Flawless V1
# 3      12:00          30              El Gran Cacao
# 4      11:45          40                   Doraemón

# %%
df_guide['channel_name'].unique()
# Out:
# array(['INFO', '101', 'AINF', 'TLEC', 'TA', 'TC', 'EV', 'GAMA', 'RTS',
#        'ECTV', 'TLRM', 'UNO', 'ORO', 'TVCE', 'ODTV', 'FOX', 'WTV', 'A&E',
#        'SONY', 'AXN', 'AMC', 'FOXL', 'TNTS', 'A3SE', 'CMDY', 'TBS', 'FX',
#        'UNI', 'SYFY', 'TRU', 'HOLATV', 'E!', 'ID', 'GLTZ', 'PASN', 'CEST',
#        'NVLA', 'LIFE', 'DH&H', 'CHIC', 'TLMD', 'GOUR', 'FOOD', 'MTV',
#        'QMMI', 'HTV', 'DTV', 'FFAM', 'HBOF', 'TOON', 'NICK', 'DSNY',
#        'DSJR', 'DSXD', 'NGKD', 'ZMOO', 'KIDS', 'BOOM', 'EWTN', 'ORBE21',
#        'ENLC', 'CINE', 'PPV', 'SMS', 'PBTV', 'VNUS', 'XTSY', 'HUST', 'TNT',
#        'GLDN', 'TCM', 'FXMV', 'CNCL', 'STUN', 'CMAX', 'PRMT', 'SUND', 'CL',
#        'DPEL', 'EDGE', 'SPAC', 'ISAT', 'NEXT', 'HBOE', 'HBO2', 'HBOP',
#        'HBOS', 'PLUS', 'MAXP', 'MAXE', 'MAXU', 'PRME', 'FPSE', 'FPSO',
#        'FOXF', 'FOXC', 'FOXM', 'FCLA', 'FOXA', 'FCIN'], dtype=object)

# %% [markdown]
# ## Omitting non national TV stations

# %%
df_nat_guide = df_guide[~df_guide.channel_name.isin(
    ['INFO', '101', 'AINF', 'DTV', 'SMS', 'PBTV', 'VNUS', 'XTSY', 'HUST', 'NEXT'])].copy()
df_nat_guide.shape
# Out:
# (30987, 8)

# %%
df = df_nat_guide.drop_duplicates(['channel_number', 'day', 'show_id', 'start_time']).copy()
print(df.shape)
df.head()
# Out:
# (21370, 8)
#   channel_name  channel_number        day          query_date       show_id  \
# 3         TLEC             177  Miércoles 2018-10-10 12:00:00  433247626775
# 4           TA             180  Miércoles 2018-10-10 12:00:00  180247762324
# 5           TC             181  Miércoles 2018-10-10 12:00:00  181247625874
# 6           EV             182  Miércoles 2018-10-10 12:00:00  182247623871
# 7         GAMA             183  Miércoles 2018-10-10 12:00:00  183248008947
#
#   start_time time_length                  title
# 3      12:00          30          El Gran Cacao
# 4      11:45          40               Doraemón
# 5      11:00          85  Los Hijos de Don Juan
# 6      10:30         150            En Contacto
# 7      12:00          30  Cocinando con Campana

# %% [markdown]
# ## Generating hash id from title

# %%
df['id'] = df['title'].apply(lambda x: hashlib.sha1(x.encode('UTF-8')).hexdigest()[:10])
df.head()
# Out:
#   channel_name  channel_number        day          query_date       show_id  \
# 3         TLEC             177  Miércoles 2018-10-10 12:00:00  433247626775
# 4           TA             180  Miércoles 2018-10-10 12:00:00  180247762324
# 5           TC             181  Miércoles 2018-10-10 12:00:00  181247625874
# 6           EV             182  Miércoles 2018-10-10 12:00:00  182247623871
# 7         GAMA             183  Miércoles 2018-10-10 12:00:00  183248008947
#
#   start_time time_length                  title          id
# 3      12:00          30          El Gran Cacao  6e262b999f
# 4      11:45          40               Doraemón  35fa610b01
# 5      11:00          85  Los Hijos de Don Juan  71ea6d42d3
# 6      10:30         150            En Contacto  f6d3df555f
# 7      12:00          30  Cocinando con Campana  4f9cc090be

# %% [markdown]
# ## Loading Programming description

# %%
df_desc = pd.io.json.json_normalize(programming_desc)
df_desc.columns = ['description', 'show_id']
print(df_desc.shape)
df_desc.head()
# Out:
# (15685, 2)
#                                          description       show_id
# 0  Un hombre y una mujer que crecieron juntos a p...  227247625150
# 1  Tres hermanos juran vengarse de la familia que...  226247625296
# 2  Una historia de amor intenso entre una joven h...  225247624192
# 3  La peculiar conductora Carmen Jara, con su per...  224247624440
# 4  T02 | E06 Asesinan a Angela Moss, una enfermer...  223247627487

# %%
df_desc = df_desc[df_desc['show_id'].isin(df['show_id'].values)]
df_desc.shape
# Out:
# (14142, 2)

# %%
# guide_index = df.set_index('show_id')
guide_index = df.drop_duplicates('show_id').set_index('show_id')
guide_index.shape
# Out:
# (14152, 8)

# %% [markdown]
# ### Appending generated id from programmming guide records

# %%
df_desc['id'] = df_desc['show_id'].apply(lambda x: guide_index.loc[str(x), 'id'])
df_desc.head()
# Out:
#                                          description       show_id          id
# 0  Un hombre y una mujer que crecieron juntos a p...  227247625150  d55a7bf26f
# 1  Tres hermanos juran vengarse de la familia que...  226247625296  05effdcbb2
# 2  Una historia de amor intenso entre una joven h...  225247624192  ac50038a04
# 3  La peculiar conductora Carmen Jara, con su per...  224247624440  5b2c0c3541
# 4  T02 | E06 Asesinan a Angela Moss, una enfermer...  223247627487  ba2dcb7806

# %% [markdown]
# ### Removing records with no `show_id`

# %%
df = df[df['show_id'].str.len() > 0]
df.shape
# Out:
# (19569, 9)

# %%
temp = df[~df['show_id'].isin(df_desc['show_id'].values)]

# %%
if temp.shape[0] > 0:
    print('WARNING: There are {} records with missing descriptions. Now removing them...'.format(temp.shape[0]))
    df = df[df['show_id'].isin(df_desc['show_id'].values)]
df.shape
# Out:
# WARNING: There are 11 records with missing descriptions. Now removing them...
# (19558, 9)

# %%
temp = df[~df['show_id'].isin(df_desc['show_id'].values)]

# %%
assert(temp.shape[0] == 0)
df.to_csv('scrapped_data/programming_guide.csv', index=False)
print('Toral Programming Guide records: %s' % df.shape[0])
print('Unique programming records: %d' % guide_index.shape[0])
# df_desc_filtered = df_desc[df_desc['show_id'].isin(df['show_id'].values)]
# df_desc_filtered.to_csv('scrapped_data/programming_desc.csv', index=False)
df_desc.to_csv('scrapped_data/programming_desc.csv', index=False)
# print('Toral Programming description records: %s' % df_desc_filtered.shape[0])
print('Toral Programming description records: %s' % df_desc.shape[0])
print('All programming data have been scrapped successfully')
print('Directv programming Guide from %s to %s' % (df['query_date'].min(), df['query_date'].max()))
# Out:
# Toral Programming Guide records: 19558
# Unique programming records: 14152
# Toral Programming description records: 14142
# All programming data have been scrapped correctly
# Directv programming Guide from 2018-10-10 12:00:00 to 2018-10-16 23:30:00

# %% [markdown]
# **NOTE** Last cell shows that Directv is not usingn a unique identifier for each show

# %%
df_desc.sort_values(['description'])
# Out:
#                                              description       show_id  \
# 13305  "La Casa del Pop" invita a los artistas más de...  269247676697
# 2295   "La Casa del Pop" invita a los artistas más de...  269247707990
# 13471  "La Casa del Pop" invita a los artistas más de...  269247676693
# 2671   "Los Hijos del Dragón", un grupo terrorista de...  526247712762
# 11537  "Maricruz" es una joven dulce e inocente que v...  227247706854
# 9751   "Maricruz" es una joven dulce e inocente que v...  227247738109
# 6543   "Maricruz" es una joven dulce e inocente que v...  227247806651
# 13133  "Maricruz" es una joven dulce e inocente que v...  227247676173
# 15165  "Maricruz" es una joven dulce e inocente que v...  227247625158
# 7743   "Maricruz" es una joven dulce e inocente que v...  227247771605
# 15524  "Maricruz" es una joven dulce e inocente que v...  227247625152
# 6178   "Maricruz" es una joven dulce e inocente que v...  227247806663
# 14818  "Maricruz" es una joven dulce e inocente que v...  227247643693
# 1805   "Maricruz" es una joven dulce e inocente que v...  227247676187
# 11176  "Maricruz" es una joven dulce e inocente que v...  227247706863
# 8801   "Maricruz" es una joven dulce e inocente que v...  227247771591
# 12578  "Maricruz" es una joven dulce e inocente que v...  227247676181
# 13856  "Maricruz" es una joven dulce e inocente que v...  227247643746
# 11861  "Maricruz" es una joven dulce e inocente que v...  227247676193
# 7078   "Maricruz" es una joven dulce e inocente que v...  227247806632
# 5821   "Maricruz" es una joven dulce e inocente que v...  227247806669
# 7414   "Maricruz" es una joven dulce e inocente que v...  227247771611
# 8105   "Maricruz" es una joven dulce e inocente que v...  227247771599
# 13477  "Maricruz" es una joven dulce e inocente que v...  227247643755
# 14233  "Maricruz" es una joven dulce e inocente que v...  227247643740
# 5698   20 individuos, 10 hombres y 10 mujeres, se enf...  264247835305
# 7199   20 individuos, 10 hombres y 10 mujeres, se enf...  264247816055
# 7237   20 individuos, 10 hombres y 10 mujeres, se enf...  264247816054
# 7138   20 individuos, 10 hombres y 10 mujeres, se enf...  264247816056
# 7285   20 individuos, 10 hombres y 10 mujeres, se enf...  264247816053
# ...                                                  ...           ...
# 6096   Óscar es un taxista extrovertido y buena gente...  189247810301
# 12122  Óscar es un taxista extrovertido y buena gente...  189247675631
# 13763  Óscar es un taxista extrovertido y buena gente...  189247643160
# 7669   Óscar es un taxista extrovertido y buena gente...  189247779789
# 15430  Óscar es un taxista extrovertido y buena gente...  189247624669
# 12171  Öykü y Ayaz se conocen de forma fortuita, y el...  225247674886
# 7721   Öykü y Ayaz se conocen de forma fortuita, y el...  225247771356
# 11569  Öykü y Ayaz se conocen de forma fortuita, y el...  225247706104
# 13425  Öykü y Ayaz se conocen de forma fortuita, y el...  225247674868
# 12743  Öykü y Ayaz se conocen de forma fortuita, y el...  225247674878
# 14858  Öykü y Ayaz se conocen de forma fortuita, y el...  225247642669
# 6147   Öykü y Ayaz se conocen de forma fortuita, y el...  225247805658
# 6702   Öykü y Ayaz se conocen de forma fortuita, y el...  225247805650
# 10352  Öykü y Ayaz se conocen de forma fortuita, y el...  225247796885
# 5767   Öykü y Ayaz se conocen de forma fortuita, y el...  225247827805
# 15102  Öykü y Ayaz se conocen de forma fortuita, y el...  225247642665
# 10407  Öykü y Ayaz se conocen de forma fortuita, y el...  225247706122
# 14407  Öykü y Ayaz se conocen de forma fortuita, y el...  225247642675
# 15482  Öykü y Ayaz se conocen de forma fortuita, y el...  225247624194
# 13169  Öykü y Ayaz se conocen de forma fortuita, y el...  225247674872
# 10444  Öykü y Ayaz se conocen de forma fortuita, y el...  225247706121
# 7113   Öykü y Ayaz se conocen de forma fortuita, y el...  225247805644
# 10504  Öykü y Ayaz se conocen de forma fortuita, y el...  225247706120
# 11804  Öykü y Ayaz se conocen de forma fortuita, y el...  225247706100
# 13823  Öykü y Ayaz se conocen de forma fortuita, y el...  225247642683
# 8266   Öykü y Ayaz se conocen de forma fortuita, y el...  225247771348
# 7354   Öykü y Ayaz se conocen de forma fortuita, y el...  225247805640
# 10561  Öykü y Ayaz se conocen de forma fortuita, y el...  225247706119
# 10595  Únase a Michael cuando revela el lado grasient...  220247709751
# 10869  Únase a Michael cuando revela el lado grasient...  220247709740
#
#                id
# 13305  afdf6a807b
# 2295   afdf6a807b
# 13471  afdf6a807b
# 2671   95e85bd847
# 11537  9537784dd4
# 9751   9537784dd4
# 6543   9537784dd4
# 13133  9537784dd4
# 15165  9537784dd4
# 7743   9537784dd4
# 15524  9537784dd4
# 6178   9537784dd4
# 14818  9537784dd4
# 1805   9537784dd4
# 11176  9537784dd4
# 8801   9537784dd4
# 12578  9537784dd4
# 13856  9537784dd4
# 11861  9537784dd4
# 7078   9537784dd4
# 5821   9537784dd4
# 7414   9537784dd4
# 8105   9537784dd4
# 13477  9537784dd4
# 14233  9537784dd4
# 5698   91a20c173b
# 7199   91a20c173b
# 7237   91a20c173b
# 7138   91a20c173b
# 7285   91a20c173b
# ...           ...
# 6096   01aa368795
# 12122  01aa368795
# 13763  01aa368795
# 7669   01aa368795
# 15430  01aa368795
# 12171  4e3f7bb126
# 7721   4e3f7bb126
# 11569  4e3f7bb126
# 13425  4e3f7bb126
# 12743  4e3f7bb126
# 14858  4e3f7bb126
# 6147   4e3f7bb126
# 6702   4e3f7bb126
# 10352  4e3f7bb126
# 5767   4e3f7bb126
# 15102  4e3f7bb126
# 10407  4e3f7bb126
# 14407  4e3f7bb126
# 15482  4e3f7bb126
# 13169  4e3f7bb126
# 10444  4e3f7bb126
# 7113   4e3f7bb126
# 10504  4e3f7bb126
# 11804  4e3f7bb126
# 13823  4e3f7bb126
# 8266   4e3f7bb126
# 7354   4e3f7bb126
# 10561  4e3f7bb126
# 10595  021839a8a9
# 10869  021839a8a9
#
# [14142 rows x 3 columns]
